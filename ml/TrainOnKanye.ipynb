# %%
from huggingface_hub import login
login()

# %%
import wandb

wandb.login(key="")

# %%
# %%bash
#
# (
#  rm -rf diffusers/examples/dreambooth/Kanye_West/.cache
#  rm -rf diffusers/examples/dreambooth/Kanye_West/.ipynb*
#  rm -rf diffusers/examples/dreambooth/man-class-images-5/.ipynb*
#  cd diffusers/examples/dreambooth/
#  export HF_HOME="/home/jupyter/datasphere/project/hf_home"
#  export MODEL_NAME="/home/jupyter/datasphere/project/hf_home/models--stabilityai--stable-diffusion-2-1/snapshots/5cae40e6a2745ae2b01ad92ae5043f95f23644d6"
#  export INSTANCE_DIR="Kanye_West"
#  export CLASS_DIR="man-class-images-5"
#  export OUTPUT_DIR="trained-sd2-Kanye_West"
#  export HF_HUB_OFFLINE=True
#  /home/jupyter/.local/bin/accelerate launch train_dreambooth_lora.py \
#   --pretrained_model_name_or_path=$MODEL_NAME  \
#   --instance_data_dir=$INSTANCE_DIR \
#   --class_data_dir=$CLASS_DIR \
#   --output_dir=$OUTPUT_DIR \
#   --with_prior_preservation --prior_loss_weight=1.0 \
#   --instance_prompt="a photo of sks_Kanye man" \
#   --class_prompt="a photo of man" \
#   --resolution=768 \
#   --train_batch_size=2 \
#   --gradient_accumulation_steps=2 --gradient_checkpointing \
#   --learning_rate=1e-4 \
#   --report_to="wandb" \
#   --lr_scheduler="cosine" \
#   --lr_warmup_steps=0 \
#   --checkpointing_steps=50 \
#   --validation_prompt="a photo of sks_Kanye man, detailed, expressive, modern" \
#   --validation_epochs=100 \
#   --seed="0" \
#   --use_8bit_adam \
#   --num_class_images=140 \
#   --max_train_steps=500 \
# )
